# %% [markdown]
# # Init Package

# %%
import pandas as pd

df_train = pd.read_csv('content/train.csv')
df_train
# Out:
#               id  MonsoonIntensity  TopographyDrainage  RiverManagement  \
# 0              0                 5                   8                5
# 1              1                 6                   7                4
# 2              2                 6                   5                6
# 3              3                 3                   4                6
# 4              4                 5                   3                2
# ...          ...               ...                 ...              ...
# 1117952  1117952                 3                   3                4
# 1117953  1117953                 2                   2                4
# 1117954  1117954                 7                   3                9
# 1117955  1117955                 7                   3                3
# 1117956  1117956                 4                   5                6
#
#          Deforestation  Urbanization  ClimateChange  DamsQuality  Siltation  \
# ...

# %%
df_test = pd.read_csv('content/test.csv')
df_test
# Out:
#              id  MonsoonIntensity  TopographyDrainage  RiverManagement  \
# 0       1117957                 4                   6                3
# 1       1117958                 4                   4                2
# 2       1117959                 1                   3                6
# 3       1117960                 2                   4                4
# 4       1117961                 6                   3                2
# ...         ...               ...                 ...              ...
# 745300  1863257                 5                   4                8
# 745301  1863258                 4                   4                2
# 745302  1863259                 5                   7                9
# 745303  1863260                 4                   7                6
# 745304  1863261                 4                   2                5
#
#         Deforestation  Urbanization  ClimateChange  DamsQuality  Siltation  \
# ...

# %% [markdown]
# # Data Cleaning & Transfromation

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1117957 entries, 0 to 1117956
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count    Dtype
# ---  ------                           --------------    -----
#  0   id                               1117957 non-null  int64
#  1   MonsoonIntensity                 1117957 non-null  int64
#  2   TopographyDrainage               1117957 non-null  int64
#  3   RiverManagement                  1117957 non-null  int64
#  4   Deforestation                    1117957 non-null  int64
#  5   Urbanization                     1117957 non-null  int64
#  6   ClimateChange                    1117957 non-null  int64
#  7   DamsQuality                      1117957 non-null  int64
#  8   Siltation                        1117957 non-null  int64
#  9   AgriculturalPractices            1117957 non-null  int64
#  10  Encroachments                    1117957 non-null  int64
# ...

# %%
df_train.describe()
# Out:
#                  id  MonsoonIntensity  TopographyDrainage  RiverManagement  \
# count  1.117957e+06      1.117957e+06        1.117957e+06     1.117957e+06
# mean   5.589780e+05      4.921450e+00        4.926671e+00     4.955322e+00
# std    3.227265e+05      2.056387e+00        2.093879e+00     2.072186e+00
# min    0.000000e+00      0.000000e+00        0.000000e+00     0.000000e+00
# 25%    2.794890e+05      3.000000e+00        3.000000e+00     4.000000e+00
# 50%    5.589780e+05      5.000000e+00        5.000000e+00     5.000000e+00
# 75%    8.384670e+05      6.000000e+00        6.000000e+00     6.000000e+00
# max    1.117956e+06      1.600000e+01        1.800000e+01     1.600000e+01
#
#        Deforestation  Urbanization  ClimateChange   DamsQuality     Siltation  \
# count   1.117957e+06  1.117957e+06   1.117957e+06  1.117957e+06  1.117957e+06
# mean    4.942240e+00  4.942517e+00   4.934093e+00  4.955878e+00  4.927791e+00
# ...

# %%
missing_values = df_train.isna().sum()
missing_values[missing_values > 0]
# Out:
# Series([], dtype: int64)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for feature in df_train.columns:
    # only show columns == WetlandLoss
    if 'WetlandLoss' in feature:
        plt.figure(figsize=(10,6))
        sns.boxplot(x=df_train[feature])
        plt.title(f'Box Plot of {feature}')
        plt.show()

# %%
# identify the outliers using the IQR method
Q1 = df_train.quantile(0.25)
Q3 = df_train.quantile(0.75)
IQR = Q3 - Q1

# filter dataframe for save line which are not outliers in numeric columns
condition = ~((df_train < (Q1 - 1.5 * IQR)) | (df_train > (Q3 + 1.5 * IQR))).any(axis=1)
df = df_train.loc[condition, df_train.columns]

# %%
for feature in df.columns:
    # only show columns == WetlandLoss
    if 'WetlandLoss' in feature:
        plt.figure(figsize=(10,6))
        sns.boxplot(x=df[feature])
        plt.title(f'Box Plot of {feature}')
        plt.show()

# %%
for feature in df_train.columns:
    if 'Deforestation' in feature:
        plt.figure(figsize=(10,6))
        sns.histplot(x=df_train[feature], kde=True)
        plt.title(f'Box Plot of {feature}')
        plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# make sure only numeric columns are processed
numeric_features = df.select_dtypes(include=['number']).columns
numeric_features

# standardize numeric feature
scaler = StandardScaler()
df[numeric_features] = scaler.fit_transform(df[numeric_features])

# %%
for feature in df.columns:
    if 'Deforestation' in feature:
        plt.figure(figsize=(10,6))
        sns.histplot(x=df[feature], kde=True)
        plt.title(f'Box Plot of {feature}')
        plt.show()

# %%
duplicates = df.duplicated()

print(f'Number of duplicates:')
print(df[duplicates])
# Out:
# Number of duplicates:
# Empty DataFrame
# Columns: [id, MonsoonIntensity, TopographyDrainage, RiverManagement, Deforestation, Urbanization, ClimateChange, DamsQuality, Siltation, AgriculturalPractices, Encroachments, IneffectiveDisasterPreparedness, DrainageSystems, CoastalVulnerability, Landslides, Watersheds, DeterioratingInfrastructure, PopulationScore, WetlandLoss, InadequatePlanning, PoliticalFactors, FloodProbability]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.describe()
# Out:
#                  id  MonsoonIntensity  TopographyDrainage  RiverManagement  \
# count  8.458860e+05      8.458860e+05        8.458860e+05     8.458860e+05
# mean   3.128825e-16     -1.722920e-16       -8.252983e-18    -1.122910e-16
# std    1.000001e+00      1.000001e+00        1.000001e+00     1.000001e+00
# min   -1.732268e+00     -2.503498e+00       -2.449018e+00    -2.065325e+00
# 25%   -8.661751e-01     -4.542981e-01       -9.492630e-01    -4.681183e-01
# 50%    2.024918e-05      5.800187e-02        5.057361e-02     6.428396e-02
# 75%    8.661002e-01      5.703019e-01        5.504919e-01     5.966862e-01
# max    1.732027e+00      2.619502e+00        2.550165e+00     2.193893e+00
#
#        Deforestation  Urbanization  ClimateChange   DamsQuality     Siltation  \
# count   8.458860e+05  8.458860e+05   8.458860e+05  8.458860e+05  8.458860e+05
# mean   -1.138030e-16 -1.484907e-17   1.193637e-16  1.572309e-16 -1.516197e-17
# ...

# %%
# count total of variables
num_vars = df.shape[1]

# determine total of rows and columns for grid subplot
n_cols = 4 # desired number of columns
n_rows = -(-num_vars // n_cols) # ceiling division for determine number of rows

# create subplot
fig, ax = plt.subplots(n_rows, n_cols, figsize=(20, n_rows * 4))

# flatten ax array for easy to iterate if needed
ax = ax.flatten()

# plot every variable
for i, column in enumerate(df.columns):
  df[column].hist(ax=ax[i], bins=20, edgecolor='black')
  ax[i].set_title(column)
  ax[i].set_xlabel('Value')
  ax[i].set_ylabel('Frequency')
  
# remove subplot that not used (if any)
for j in range(i+1, len(ax)):
  fig.delaxes(ax[j])
  
# adjust layout to make it neater
plt.tight_layout()
plt.show()

# %%
# count corelation between traget variable and all other variables
target_corr = df.corr()['FloodProbability']

# (optional) sort the correlation value by power of the correlation
target_corr_sorted = target_corr.abs().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
target_corr_sorted.plot(kind='bar')
plt.title('Correlation with SalePrice')
plt.xlabel('Variables')
plt.ylabel('Correlation Coefficient')
plt.show()

# %%
import sklearn
from sklearn import datasets

# seperate x feature and y target
X = df.drop(columns=['FloodProbability'])
y = df['FloodProbability']

from sklearn.model_selection import train_test_split

# split data into train and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# count long/total data
print(f'Total data: {len(X)}')

# count long/total data for train and test set
print(f'Total data for train set: {len(X_train)}')
print(f'Total data for test set: {len(X_test)}')
# Out:
# Total data: 845886
# Total data for train set: 676708
# Total data for test set: 169178

# %%
# LARS
from sklearn import linear_model
lars = linear_model.Lars(n_nonzero_coefs=1).fit(X_train, y_train)

pred_lars =lars.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae_lars = mean_absolute_error(y_test, pred_lars)
mse_lars = mean_squared_error(y_test, pred_lars)
r2_lars = r2_score(y_test, pred_lars)

print(f'MAE: {mae_lars}')
print(f'MSE: {mse_lars}')
print(f'R2: {r2_lars}')
# Out:
# MAE: 0.806496586211278
# MSE: 0.9982455301765464
# R2: 0.0007638833508519793

# %%
# create dictionary for save the result
data = {
    'Model': ['LARS'],
    'MAE': [mae_lars],
    'MSE': [mse_lars],
    'R2': [r2_lars]
}

# convert dictionary to dataframe
df_results = pd.DataFrame(data, index=['Lars'])
df_results
# Out:
#      Model       MAE       MSE        R2
# Lars  LARS  0.806497  0.998246  0.000764

# %%
# Linear Regression
from sklearn.linear_model import LinearRegression
LR = LinearRegression().fit(X_train, y_train)

pred_LR = LR.predict(X_test)

mae_LR = mean_absolute_error(y_test, pred_LR)
mse_LR = mean_squared_error(y_test, pred_LR)
r2_LR = r2_score(y_test, pred_LR)

print(f'MAE: {mae_LR}')
print(f'MSE: {mse_LR}')
print(f'R2: {r2_LR}')
# Out:
# MAE: 0.32914155892050634
# MSE: 0.17129638555662158
# R2: 0.8285336323325565

# %%
lr = 'Linear Regression'

df_results.loc[lr] = [lr, mae_LR, mse_LR, r2_LR]
df_results
# Out:
#                                Model       MAE       MSE        R2
# Lars                            LARS  0.806497  0.998246  0.000764
# Linear Regression  Linear Regression  0.329142  0.171296  0.828534

# %%
# Gradient Boosting Regressor
from sklearn.ensemble import GradientBoostingRegressor

GBR = GradientBoostingRegressor(random_state=184)
GBR.fit(X_train, y_train)

pred_GBR = GBR.predict(X_test)

mae_GBR = mean_absolute_error(y_test, pred_GBR)
mse_GBR = mean_squared_error(y_test, pred_GBR)
r2_GBR = r2_score(y_test, pred_GBR)

print(f'MAE: {mae_GBR}')
print(f'MSE: {mse_GBR}')
print(f'R2: {r2_GBR}')
# Out:
# MAE: 0.5126715936448323
# MSE: 0.3804907514322629
# R2: 0.6191316771387398
